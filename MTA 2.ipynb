# %% [markdown]
# #MTA Document - 2

# %% [markdown]
# #1

# %%
#1 Which expression ecalutes to 4?

# %%
7-2*3
# Out:
# 1

# %%
7//2-3
# Out:
# 0

# %%
7/2*3
# Out:
# 10.5

# %%
7%2+3
# Out:
# 4

# %% [markdown]
# #2 Not Understand

# %%
#2 Consider the code

from sys import argv
sum=0
for i in range(2,len(argv)):
  sum += float(argv[i])
print("The Average for {0} is {1:.2f}".format(argv[1],sum/(len(argv)-2)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-3638993417.py in <cell line: 0>()
#       3 sum=0
#       4 for i in range(2,len(argv)):
# ----> 5   sum += float(argv[i])
#       6 print("The Average for {0} is {1:.2f}".format(argv[1],sum/(len(argv)-2)))
#
# ValueError: could not convert string to float: '/root/.local/share/jupyter/runtime/kernel-f39ebe95-761d-486c-9e7d-a385aa184793.json'

# %% [markdown]
# #3

# %%
#4 Consider the code
x =3
x +=1
#Which line sholuld be inserted as Line-1 so that x value will become 16?

# %%
x**=2
x
# Out:
# 16

# %%
x*=2
x
# Out:
# 32

# %%
x+=2
x
# Out:
# 34

# %%
x-=2
x
# Out:
# 30

# %% [markdown]
# #4

# %%
#Consider the following code 
print(type(input("Enter some value: ")))
# if we enter 10 and 10.00 individually for every run whats is the output?
# Out:
# Enter some value:  10
# <class 'str'>

# %%
print(type(input("Enter some value: ")))# Input allways give str
# Out:
# Enter some value:  10.00
# <class 'str'>

# %% [markdown]
# #5

# %%
# 5 Consider the python code:
a=['a','b','c','d']
for i in a:
    a.append(i.upper())
print(a)

# %%
#MemoryError thrown at runtime

# %% [markdown]
# #6

# %%
#6 Consider the variable declarations:
a='5'
b='2'
# which of the following expressions are of type str

# %%
a*b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 a*b
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
a*2
# Out:
# '55'

# %%
a+b
# Out:
# '52'

# %%
a-b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 a-b
#
# TypeError: unsupported operand type(s) for -: 'str' and 'str'

# %% [markdown]
# #8

# %%
#Consider the code 
a=7
b=3
c=5
d=1
#which line of the code assigns 9 to the output

# %%
a%c+1
# Out:
# 3

# %%
a+d*2
# Out:
# 9

# %%
a+c//d
# Out:
# 12

# %%
c*d-1
# Out:
# 4

# %% [markdown]
# #9 Not Understand

# %% [markdown]
# #10

# %%
#10
6//4%5+2**3-2//3
# Out:
# 9

# %% [markdown]
# #11

# %%
# 11 Which line of the code will assign 'TT'to the output?
x='TEXT'

# %%
x[0]+x[-1]
# Out:
# 'TT'

# %%
x[0]+x[3]
# Out:
# 'TT'

# %%
x[-1]+x[-4]
# Out:
# 'TT'

# %% [markdown]
# #12

# %%
#12 Consider the python code 
print(10==10 and 20!=20)
print(10==10 or 20!=20)
print( not 10==10)
# Out:
# False
# True
# False

# %% [markdown]
# #13

# %%
#13 Consider the code 
a=float('123.456')
#which expression evaluates to 2?

# %%
bool(a)
# Out:
# True

# %%
int(a)+False
# Out:
# 123

# %%
str(a)
# Out:
# '123.456'

# %%
bool(a)+True
# Out:
# 2

# %% [markdown]
# #14

# %%
#14 You are intern from xyz cars company.You have to create a function that calculates the 
# average velocity of vehicals on 2640 foot(1/2 miles)track
#Consider code # not understand

# %%
distance=int(input('Enter the distance travelled in feet: '))
distance_miles=distance/5280
time=int(input('Enter the time elapsed in seconds: '))
time_hours=time/3600
velocity=distance_miles/time_hours
print('The average Velocity:',velocity,'miles/hour')
# Out:
# Enter the distance travelled in feet:  2640
# Enter the time elapsed in seconds:  30
# The average Velocity: 60.0 miles/hour

# %%
distance=float(input('Enter the distance travelled in feet: '))
distance_miles=distance/5280
time=float(input('Enter the time elapsed in seconds: '))
time_hours=time/3600
velocity=distance_miles/time_hours
print('The average Velocity:',velocity,'miles/hour')
# Out:
# Enter the distance travelled in feet:  2640
# Enter the time elapsed in seconds:  30
# The average Velocity: 60.0 miles/hour

# %% [markdown]
# #15

# %%
#15 Thw XYZ Company has hied you as an intern on the coding team that creates a e commerce application .
# You must write a script that asks the user for a value .The value must be used as a whole numbers in a valculate even id the user enters a decimal value 
# whucg if the fillowing meets this requirement?

# %%
total_items=int(float(input("How many items you reqired?")))
# Out:
# How many items you reqired? 55.5

# %% [markdown]
# #16

# %%
#16 In which of the following cases ,True will be printed to the console?

# %%
print('r' in 'durga')
# Out:
# True

# %%
print('is' in 'This IS a Fake News')
# Out:
# True

# %%
a=45
b=45
print(a is not b)
# Out:
# False

# %%
s1='The Python Course'
s2='The python Course'.upper()
print(s1 is s2)
# Out:
# False

# %%
x=[1,2,3]
y=[1,2,3]
print(x is y)
# Out:
# False

# %% [markdown]
# #17

# %%
#17 consider the code 
x=2
y=6
x+=2**3
print(x)
# Out:
# 10

# %%
x//=y//2//3
print(x)
# Out:
# 10

# %% [markdown]
# #18 Not Understand

# %% [markdown]
# #19

# %%
#19 if the user enters 12345 as input , which of the following code will print 123456 to consol ?
count=int(input('Enter count value'))
print(count+1)
# Out:
# Enter count value 12345
# 12346

# %%
count=eval(input("Enter count value:"))
print(count+1)
# Out:
# Enter count value: 12345
# 12346

# %%
count=input('Enter count value')
print(count+1)
# Out:
# Enter count value 12345
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 2
#       1 count=input('Enter count value')
# ----> 2 print(count+1)
#
# TypeError: can only concatenate str (not "int") to str

# %%
count=input("Enter count value:")
print(int(count)+1)
# Out:
# Enter count value: 12345
# 12346

# %% [markdown]
# #20

# %%
#20 consider the code 
t=([10,20],10,False)
#which line of the code assigns class list to x

# %%
x=type(t[0])
x
# Out:
# list

# %% [markdown]
# #21

# %%
#21 Which expression would evaluate to 2?

# %%
11/2
# Out:
# 5.5

# %%
22%5
# Out:
# 2

# %%
13//4
# Out:
# 3

# %%
3**2
# Out:
# 9

# %% [markdown]
# #22

# %%
#22 Consider the code 
x=3/3+3**3-3
print(x)
# Out:
# 25.0

# %% [markdown]
# #23

# %%
#23  Consider the python code 
result=str(bool(1) + float(10)/float(2))
print(result)
print(type(result))
# Out:
# 6.0
# <class 'str'>

# %% [markdown]
# #23

# %% [markdown]
# #24 Not Understand

# %% [markdown]
# #25

# %%
#25 You develop a python application for your company.You required to accept input from the user
#and print that information to the user screen.
#consider the code 
print('Enter your Name:')
name=input
print(name)
# Out:
# Enter your Name:
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x000001AFF7AFD160>>

# %%
print('Enter your name: ')
input(name)
print(name)
# Out:
# Enter your name:
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x000001AFF7AFD160>> ehjk
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x000001AFF7AFD160>>

# %%
print('Enter Your Name: ')
input('name')
print(name)
# Out:
# Enter Your Name:
# name gj
# <bound method Kernel.raw_input of <ipykernel.ipkernel.IPythonKernel object at 0x000001AFF7AFD160>>

# %%
print('Enter Your Name: ')
name=input()
print(name)
# Out:
# Enter Your Name:
#  Sushil
# Sushil

# %% [markdown]
# #26

# %%
#which of the following are valid statements?
#True and false evaluates to false 
#true+1 evalutes to2

# %%
type('')
# Out:
# str

# %% [markdown]
# #27

# %%
#27 Consider the code 
print(not 0)
print(not 10)
print(not '')
print(not 'durga')
print(not None)
# Out:
# True
# False
# True
# False
# True

# %% [markdown]
# #28

# %%
#28 Consider the python code 
l1=['sunny','bunny','chinny','vinny']
l2=['sunny','bunny','chinny','vinny']
print(l1 is not l2)
print(l1 != l2)
# Out:
# True
# False

# %%
l1=l2
print(l1 is not l2)
print(l1 != l2)
# Out:
# False
# False

# %% [markdown]
# #29

# %%
#29 In which of the following cases we wil get class int as output?
x=2**2**2
print(x)
print(type(x))
# Out:
# 16
# <class 'int'>

# %% [markdown]
# #30

# %%
#30 Consider the code:
s='DURGA SOFT'
#which of the following lines will assign 9 to variable result?
len(s)
# Out:
# 10

# %%
len(s.strip())
# Out:
# 10

# %%
len(s.replace(' ',''))
# Out:
# 9

# %% [markdown]
# #31 Not understand

# %% [markdown]
# #32

# %%
#32 Consider the varible declaration
b = 'BANANA'
# Which of the following lines will print 'AA' to the consol?

# %%
b[1]+b[3]
# Out:
# 'AA'

# %%
b[3]+b[5]
# Out:
# 'AA'

# %%
b[1]+b[5]
# Out:
# 'AA'

# %%
b[-1]+b[-3]
# Out:
# 'AA'

# %% [markdown]
# #33

# %%
# 33 False,True,true,true

# %% [markdown]
# #34

# %%
#34 Consider following code 
v1=1
v2=0
v1=v1^v2
v2=v1^v2
v1=v1^v2
print(v1)
# Out:
# 0

# %% [markdown]
# #35

# %%
#35 Consider the code 
count=input("enter the number of the customers of bank: ")
output=int(count)+5
print(output)
# Out:
# enter the number of the customers of bank:  15
# 20

# %% [markdown]
# #36

# %%
#36Consider the code 
x='10'
y='20'
x+y
type(x+y)
# Out:
# str

# %% [markdown]
# #37

# %%
#37 Which of the following string declaration spans more than one line and considers whitespace properly when the string is orinted to the consol?

# %%
S1 = 'Bharat\n       Software\n       Solutions'
s1
# Out:
# 'Bhart\n software\n Solution'

# %%
s2 =  """ Bharat
       Software
       Solutions """
s2
# Out:
# ' Bharat\n       Software\n       Solutions '

# %%
s3 = ' Bharat
       Software
       Solutions'
s3
# Out:
#   Cell In[10], line 1
#     s3 = ' Bharat
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
S4 = " Bharat
       Software
       Solutions"
s4
# Out:
#   Cell In[11], line 1
#     S4 = " Bharat
#          ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# #38

# %%
#38 Consider the code 
lst=[7,8,9]
b = lst[:]
print(b is lst)
print(b == lst)
# Out:
# False
# True

# %% [markdown]
# #39

# %%
# 39 Which of the following statements are valid?
b =False+5-True+35//4  #Correct option
b
# Out:
# 12

# %%
S = "Sachin Tendulkar is cricket's great player"
S
# Out:
# "Sachin Tendulkar is cricket's great player"

# %%
c=((7/2)+(False or True)+(9%3)) #Correct option
c
# Out:
# 4.5

# %%
result=456+456.0
result
type(result)
# Out:
# float

# %% [markdown]
# #40

# %% [markdown]
# #40 We are developing an app in which student will provide collage name and city as input . If the student provide callege name as BHARATSOF and city as pune , then our application has to provide the following greeting message
# welcome to BHARATSOFT in Pune

# %%
college_name=input("Enter Your College Name:- ")
city = input("Enter Your City Name:- ")
print("Welcome to {} in {}.".format(college_name,city))
# Out:
# Enter Your College Name:-  BHARATSOFT
# Enter Your City Name:-  PUNE
# Welcome to BHARATSOFT in PUNE.
