# %% [markdown]
# MTA 4

# %% [markdown]
# #1

# %%
#1 Which of the following is False

# %%
# A try statement can have one or more except clauses
#  TRUE
# A try statement can have a finally clause without an except clause
#  TRUE
# A try statement can have a finally clause and an except clause
#  TRUE
# A try statement can have one or more finally clauses
#  FALSE

# %% [markdown]
# #2

# %%
#2 Which type of exception will be raised if we are trying to call a method on the inappropriate object? 
# IndexError 
# TypeError 
# AttributeError ✅
# None of these

# %% [markdown]
# #3

# %%
#3 Consider the code 
f = open("abc.txt", "w")
f.write("Hello")
f.close()

# %%
f = open("abc.txt", "r")
print(f.readall())
f.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 f = open("abc.txt", "r")
# ----> 2 print(f.readall())
#       3 f.close()
#
# AttributeError: '_io.TextIOWrapper' object has no attribute 'readall'

# %% [markdown]
# #4

# %%
#4 Consider the code 
def f1():
    try:
        return 1 
    finally:
        return 2
x=f1()
print(x)
#finally block return has higher priority than try block return
# Out:
# 2

# %% [markdown]
# #5

# %%
#5 Which of the following are True?

# ️A try block can have any number of except blocks
# A try block should be associated with at most one finally block
# ️A try block should be associated with at most one else block
# All the above ✅

# Any number of except blocks allowed
# Only one finally block allowed
# Only one else block allowed

# %% [markdown]
# #6 Not Understand

# %% [raw]
# 6 The base class for all exceptions in python is:
# ExceptionBase
# BaseException ✅
# Exception
# EOFError
#
# BaseException
#     |
#     └── Exception
#             |
#             ├── ValueError
#             ├── TypeError
#             ├── ZeroDivisionError
#             └── IndexError

# %% [markdown]
# #7

# %%
# 7 Which of the following is True about else block?

# else block will be executed if there is no exception in try block
# Without writing except block we cannot write else block
# For the same try we can write atmost one else block
# All the above ✅

# else block executes only if no exception occurs in try
# else block cannot be written without except
# For one try block, only one else block is allowed

# %% [markdown]
# #8

# %%
#8 
try:
    print('try')
except:
    print('except')
else:
    print('else')
finally:
    print('finally')
# Out:
# try
# else
# finally

# %% [markdown]
# #9

# %%
#9 
try:
    print('try')
    print(10/0)
except:
    print('except')
else:
    print('else')
finally:
    print('finally')
# Out:
# try
# except
# finally

# %% [markdown]
# #10

# %%
#10 
try:
    print('try')
    print(10/0)
else:
    print('else')
except:
    print('except')
finally:
    print('finally')
# Out:
#   Cell In[16], line 5
#     else:
#     ^
# SyntaxError: expected 'except' or 'finally' block

# %% [markdown]
# #11

# %%
#11 Consider the code :
f=open("xyz.txt")
print(f.read())
f.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 2
#       1 #11 Consider the code :
# ----> 2 f=open("xyz.txt")
#       3 print(f.read())
#       4 f.close()
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'xyz.txt'

# %%
f = None
try:
    f=open("xyz.txt")
except FileNotFoundError:
    print("File does not exist")
else:
    print(f.read())
finally:
    if f != None:
        f.close()
# Out:
# File does not exist

# %% [markdown]
# #12

# %%
#12 Consider the code 
a=10
b=20
c="30"
result=a+b+c
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 5
#       3 b=20
#       4 c="30"
# ----> 5 result=a+b+c
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# #13

# %%
#13 consider the code

# %%
prices=[30.5,'40.5',10.5]
total = 0
for price in prices:
    total += float(price)
print(total)
# Out:
# 81.5

# %% [markdown]
# #14 consider the code

# %%
prices=[10,"20",30,40,"50"]
total = 0
for price in prices:
    total += int(price)
print(total)
# Out:
# 150

# %%
prices=[10,"20",30,40,"50"]
total = 0
for price in prices:
    total += float(price)
print(total)
# Out:
# 150.0

# %% [markdown]
# #15

# %%
#15 consider ths code 
courses={1:'java',2:'Scala',3:'Python'}
for i in range(1,5):
    if i in courses:
        print(courses[i])
# Out:
# java
# Scala
# Python

# %%
courses={1:'java',2:'Scala',3:'Python'}
for i in courses:
    print(courses[i])
# Out:
# java
# Scala
# Python

# %%
courses={1:'java',2:'Scala',3:'Python'}
for i in range(1,4):
    print(courses[i])
# Out:
# java
# Scala
# Python

# %% [markdown]
# #16

# %%
#16 Consider the code 
def area(b,w):
    return B*w
print(area(10,20))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 4
#       2 def area(b,w):
#       3     return B*w
# ----> 4 print(area(10,20))
#
# Cell In[32], line 3, in area(b, w)
#       2 def area(b,w):
# ----> 3     return B*w
#
# NameError: name 'B' is not defined

# %% [markdown]
# #17

# %%
#17 Consider the code 
def get_score(total=0,valid=0):
    result=int(valid)/int(total)
    return result

# %%
score1=get_score(40,4)
score1
# Out:
# 0.1

# %%
score2=get_score("40","4")
score2
# Out:
# 0.1

# %%
score4=get_score(40)
score4
# Out:
# 0.0

# %%
score4=get_score(0,10)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 score4=get_score(0,10)
#
# Cell In[34], line 3, in get_score(total, valid)
#       2 def get_score(total=0,valid=0):
# ----> 3     result=int(valid)/int(total)
#       4     return result
#
# ZeroDivisionError: division by zero

# %% [markdown]
# #18

# %%
#18 Consider the code 
data = []
def get_data():
    for i in range(1,5):
        marks= input("Enter Marks: ")
        data.append(marks)

def get_avg():
    total = 0
    for mark in data:
        total += mark
    return total/len(data)
get_data()
print(get_avg())
# Out:
# Enter Marks:  10
# Enter Marks:  20
# Enter Marks:  30
# Enter Marks:  40
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 14
#      12     return total/len(data)
#      13 get_data()
# ---> 14 print(get_avg())
#
# Cell In[50], line 11, in get_avg()
#       9 total = 0
#      10 for mark in data:
# ---> 11     total += mark
#      12 return total/len(data)
#
# TypeError: unsupported operand type(s) for +=: 'int' and 'str'

# %% [markdown]
# #19 consider the code  Not Understand

# %%
a= 18 
b =0
try:
    print(a/b)
except ZeroDivisionError as e:
    print('Exception Type:',e.__class__.__name__)
# Out:
# Exception Type: ZeroDivisionError

# %%
a= 18 
b =0
try:
    print(a/b)
except ZeroDivisionError as e:
    print('Exception Type:',type(e).__name__)
# Out:
# Exception Type: ZeroDivisionError

# %%
a= 18 
b =0
try:
    print(a/b)
except ZeroDivisionError as e:
    print('Exception Type:',e)
# Out:
# Exception Type: division by zero

# %% [markdown]
# #20

# %%
#20 Which of the following is vaild way of creating our own custom exception?

# %%
class MyException(Exception):
    pass

# %% [raw]
# BaseException
#    └── Exception
#          ├── ValueError
#          ├── TypeError
#          └── YourCustomException

# %% [markdown]
# #21

# %%
#21 consider the code 
x=int(input("Enter First Number"))
y=int(input("Enter Secound Number"))
try:
    print(x/y)
except(ZeroDivisionError,ValueError) as e:
    print(e)
# Out:
# Enter First Number 5
# Enter Secound Number 0
# division by zero

# %%
x=int(input("Enter First Number"))
y=int(input("Enter Secound Number"))
try:
    print(x/y)
except(ZeroDivisionError,ValueError) as e:
    print("Error Type:", type(e).__name__)
    print("Message:", e)
# Out:
# Enter First Number 5
# Enter Secound Number 0
# Error Type: ZeroDivisionError
# Message: division by zero

# %% [markdown]
# #22

# %%
#22 Consider the code

# %%
import os
def get_data(filename,mode):
    if os.path.isfile(filename):
        with open(filename,'r')as file:
            return file.readline()
    else:
        return None
get_data("abc.txt",'r')
# Out:
# 'Hello'

# %%
import os
def get_data(filename,mode):
    if os.path.isfile(filename):
        with open(filename,'r')as file:
            return file.readline()
    else:
        return None
get_data("xyz.txt",'r')

# %%
with open("inventory.txt", "w") as f:
    f.write("Apple\n")
    f.write("Banana\n")
    f.write("Mango\n")

print("File created successfully")
# Out:
# File created successfully

# %% [markdown]
# #23

# %%
#23
inventory = open('inventory.txt','r')
eof = False
while eof == False:
    line= inventory.readline()
    if line!= '':
        if line != '\n':
            print(line,end='')
    else:
        print('End of file')
        eof=True
        inventory.close()
# Out:
# Apple
# Banana
# Mango
# End of file

# %% [markdown]
# #24

# %%
#24 
a=open('xyz.txt','w+')

# %%
a.close()

# %% [markdown]
# #25

# %%
#25 
import os 
def read_file(file):
    line=None
    if os.path.isfile(file):
        data=open(file,'r')
    while line != '':
        line=data.readline()
        print(line)

# %%
read_file('abc.txt')
# Out:
# Hello

# %% [markdown]
# #26

# %%
#26 
with open("in.txt", "w") as f:
    f.write("Apple\n")
    f.write("Banana\n")
    f.write("Mango\n")
print("File created successfully")
# Out:
# File created successfully

# %%
#26 consider the code 
import sys 
try:
    file_in=open('in.txt','r')
    file_out=open('out.txt','w+')
except IOError:
    print('cannot open',file_name)
else:
    i=1
    for line in file_in:
        print(line.rstrip())
        file_out.write(str(i)+":"+line)
        i=i+1
    file_in.close()
    file_out.close()
# Out:
# Apple
# Banana
# Mango

# %% [markdown]
# #27

# %%
# consider the file txt
values = 0

try:
    f = open('new.txt', 'r')
    content = f.readlines()
    for line in content:
        values += float(line.split()[1])
    f.close()
except Exception:
    print("Unable to open the file")

print(values)
# Out:
# 100.0

# %% [markdown]
# #28

# %%
text = """Lorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat.
Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur.
Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum."""

# %%
with open("abcd.txt", "w") as f:
    f.write(text)

print("File created and saved in working directory")
# Out:
# File created and saved in working directory

# %%
try:
    f=open('abcd.txt','r')
    data=f.read()
except:
    print('unable to open the file')
print(data)
# Out:
# Lorem ipsum dolor sit amet, consectetur adipisicing elit, sed do eiusmod tempor incididunt ut labore et dolore magna aliqua.
# Ut enim ad minim veniam, quis nostrud exercitation ullamco laboris nisi ut aliquip ex ea commodo consequat.
# Duis aute irure dolor in reprehenderit in voluptate velit esse cillum dolore eu fugiat nulla pariatur.
# Excepteur sint occaecat cupidatat non proident, sunt in culpa qui officia deserunt mollit anim id est laborum.

# %% [markdown]
# #29

# %%
#29
f=open('abcde.txt','w')
f.write('Python Certification')
f.close()
print("File created successfully")

# %%
#29
with open('abcdef.txt') as f:
    data=f.read()
print(data)
# Out:
# File created successfully

# %%
with open('abcdef.txt') as f:
    data=f.read()
print(data)
# Out:
# BHARATSOFT,50,60,70,80,90MICROSOFT,10,20,30,40,50

# %%
with open('abcdef.txt','r') as f:
    data=f.read()
print(data)
# Out:
# BHARATSOFT,50,60,70,80,90 MICROSOFT,10,20,30,40,50

# %% [markdown]
# #31

# %%
#31 
f=open('voters_list.txt','w')
f.write('Sushil,Omkar')
f.close()
print("File created successfully")
# Out:
# File created successfully

# %%
with open('voters_list.txt','a+') as f:
    f.write(" New voters info")
    f.seek(0)
    data=f.read()
    print(data)

# %% [markdown]
# #32

# %%
#32 You are creating a function that manipulates a number. 
# The function has the following requirements:
# A float passed to the function The function must take absolute value of 
# the float Any decimal points after the integer must be removed. 
# Which two math functions should be used?

# %%
import math
math.fabs(-123.456)
# Out:
# 123.456

# %%
math.floor(-123.456)
# Out:
# -124

# %% [markdown]
# #33

# %%
#You are writing an application that uses the sqrt function.The program must reference the function using the name sq
# which of the following import statement req to use ?

# %%
from math import sqrt as sq

# %%
import math sqrt as sq
# Out:
#   Cell In[84], line 1
#     import math sqrt as sq
#                 ^
# SyntaxError: invalid syntax

# %%
import sqrt math as sq
# Out:
#   Cell In[85], line 1
#     import sqrt math as sq
#                 ^
# SyntaxError: invalid syntax

# %%
from math sqrt as sq
# Out:
#   Cell In[86], line 1
#     from math sqrt as sq
#               ^
# SyntaxError: invalid syntax

# %% [markdown]
# #34

# %%
#34 consider the code 
import math 
l = [str(round(math.pi)) for i in range(1,6)]
print(l)
# Out:
# ['3', '3', '3', '3', '3']

# %% [markdown]
# #35

# %%
#35You are writing code that generates a random integer with a min value of 5 
# and max value of 11.Which of the following2 function we req to use?

# %%
import random
random.randint(5,11)
# Out:
# 6

# %%
import random
random.randrange(5,12,1)
# Out:
# 11

# %% [markdown]
# #36

# %%
# 36 Consider the following code 
import random
fruits=['Apple','Mango','Orange','Lemon']

# %%
print(random.sample(fruits,3)[0])
# Out:
# Apple

# %%
print(random.choice(fruits))
# Out:
# Orange

# %% [markdown]
# #37

# %%
#37 we are develoing an application for the client req. as the part of that we have to create a list of 7 random integers bet 1 to 7 inclusive
#which of the following code should be used?

# %%
import random 
randints=[random.randint(1,7) for i in range(1,8)]
print(randints)
# Out:
# [5, 6, 3, 4, 2, 3, 2]

# %% [markdown]
# #38

# %%
#38Consider the following code 
import random
fruits=['Apple','Mango','Orange','Lemon']
random_list=[random.choice(fruits)[:2] for i in range(3)]
print(''.join(random_list))
# Out:
# ApMaMa

# %% [markdown]
# #39 creat function and calculte area of circle

# %%
import math
def find_area(r):
    return math.pi*math.pow(r,2)

find_area(3)
# Out:
# 28.274333882308138

# %% [markdown]
# #40 Consider the code

# %%
import random 
print(int(random.random()*5))
# Out:
# 3

# %%
#it will print a random int value from 0to4
